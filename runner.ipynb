# %%
import train_nb
# Out:
# {'batch_size': 1,
#  'beta1': 0.5,
#  'cuda': 'store_true',
#  'dataset': '',
#  'direction': 'b2a',
#  'epoch_count': 1,
#  'input_nc': 3,
#  'lamb': 10,
#  'lr': 0.0002,
#  'lr_decay_iters': 50,
#  'lr_policy': 'lambda',
#  'ndf': 64,
#  'ngf': 64,
#  'niter': 100,
#  'niter_decay': 100,
#  'output_nc': 3,
#  'seed': 123,
#  'test_batch_size': 1,
#  'threads': 4}

# %%
train_nb.opt['dataset'] = 'facades'
train_nb.opt['niter'] = 5

# %%
init_kwargs = {
    'wb_project': "pix2pix",
    'wb_entity': "yusufjkhan1",
    'wb_hp_config': train_nb.opt
}

# %%
model = train_nb.pix2pix(**init_kwargs)

# %%
model.run()
# Out:
# wandb: Currently logged in as: yusufjkhan1 (use `wandb login --relogin` to force relogin)
#                     Syncing run <strong><a href="https://wandb.ai/yusufjkhan1/pix2pix/runs/3i8uh867" target="_blank">luminous-floret-9</a></strong> to <a href="https://wandb.ai/yusufjkhan1/pix2pix" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# ===> Loading datasets
# ===> Building models
# device: cuda:0
# wandb: logging graph, to disable use `wandb.watch(log_graph=False)`
# wandb: logging graph, to disable use `wandb.watch(log_graph=False)`
# initialize network with normal
# initialize network with normal
# ===> Epoch[1](1/400): Loss_D: 1.6859 Loss_G: 17.1135
# learning rate = 0.0002000
# learning rate = 0.0002000
# ===> Avg. PSNR: 6.7077 dB
# Checkpoint saved to checkpointfacades
# ===> Epoch[2](1/400): Loss_D: 0.2424 Loss_G: 3.3428
# learning rate = 0.0002000
# learning rate = 0.0002000
# ...
